# %%
from keras import optimizers
from keras import layers
from keras.utils import to_categorical
import tensorflow as tf
import numpy as np
from sklearn.model_selection import train_test_split

tf.__version__

# %%
WINDOW_SIZE = 300 # 60hz * 5sec
SENSOR_NUM = 4 
SENSOR_NAME = ["Gravity", "Linear_accelerator", "Gyroscope", "Magnetic"]

SENSOR_FEATURES = 3 # each sensor has x, y, z features
INPUT_SHAPE = (300, 3)

DROP_RATE = 0.2
CLASS_NUM = 7

CLASS_NAME_7 = ["Still", "Walking", "Manual", "Electric", "Bus", "Subway", "Car"]
# CLASS_NAME_5 = ["Still", "Manual", "Electric", "Subway", "Car"]

BATCH_SIZE = 128
NUM_EPOCHS = 30

class MultiCNN(tf.keras.Model):

    def __init__(self):
        super(MultiCNN, self).__init__()
        
        self.conv_layers = []
        
        for _ in range(SENSOR_NUM):
            conv_layers = [
                layers.Conv1D(filters=32, kernel_size=3, strides=1, padding='Same', activation="relu", input_shape=INPUT_SHAPE),
                layers.MaxPooling1D(pool_size=2, strides=2),
                layers.Conv1D(filters=64, kernel_size=3, strides=1, padding='Same', activation='relu'),
                layers.MaxPooling1D(pool_size=2, strides=2),
                layers.Conv1D(filters=128, kernel_size=3, strides=1, padding='Same', activation='relu'),
                layers.MaxPooling1D(pool_size=2, strides=2),
                layers.Flatten()
            ]
            self.conv_layers.append(conv_layers)
        
        self.concat = layers.Concatenate(axis=-1)
        self.dense1 = layers.Dense(256, activation="relu")
        self.dropout = layers.Dropout(DROP_RATE)
        self.output_layer = layers.Dense(CLASS_NUM, activation='softmax')
    
    # Define forward procedures
    def call(self, inputs, training=False):
        x = []
        for i in range(SENSOR_NUM):
            xi = inputs[i]
            for layer in self.conv_layers[i]:
                xi = layer(xi)
            x.append(xi)
        x = self.concat(x)
        x = self.dense1(x)
        
        if training:
            x = self.dropout(x, training=training)
        return self.output_layer(x)
    
    # TFlite에서 학습을 진행하려면 tf.function으로 감싸줘야 함.
    @tf.function(input_signature=[
        tf.TensorSpec(shape=[SENSOR_NUM, None, WINDOW_SIZE, SENSOR_FEATURES], dtype=tf.float32),
        tf.TensorSpec(shape=[None, CLASS_NUM], dtype=tf.float32)
    ])
    def train(self, x, y):
        with tf.GradientTape() as tape:
            inputs = [tf.gather(x, i, axis=0) for i in range(SENSOR_NUM)]
            prediction = self(inputs, training=True)
            loss = tf.keras.losses.CategoricalCrossentropy()(y, prediction)
        gradients = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        result = {"loss": loss}
        return result
    
    @tf.function(input_signature=[
        tf.TensorSpec(shape=[SENSOR_NUM, None, WINDOW_SIZE, SENSOR_FEATURES], dtype=tf.float32),
        tf.TensorSpec(shape=[None, CLASS_NUM], dtype=tf.float32)
    ])
    def valid(self, x, y):
        inputs = [tf.gather(x, i, axis=0) for i in range(SENSOR_NUM)]
        prediction = self(inputs, training=False)  
        loss = tf.keras.losses.CategoricalCrossentropy()(y, prediction)
        result = {"val_loss": loss}
        return result
    
    @tf.function(input_signature=[
        tf.TensorSpec(shape=[SENSOR_NUM, None, WINDOW_SIZE, SENSOR_FEATURES], dtype=tf.float32)
    ])
    def infer(self, x):
        inputs = [tf.gather(x, i, axis=0) for i in range(SENSOR_NUM)]
        logits = self(inputs, training=False)
        probabilities = tf.nn.softmax(logits, axis=-1)
        return {
            "output": probabilities,
            "logits": logits
        }
        
    @tf.function(input_signature=[tf.TensorSpec(shape=[], dtype=tf.string)])
    def save(self, checkpoint_path):
        tensor_names = [weight.name for weight in self.weights]
        tensors_to_save = [weight.read_value() for weight in self.weights]
        tf.raw_ops.Save(
            filename=checkpoint_path, tensor_names=tensor_names,
            data=tensors_to_save, name='save')
        return {
            "checkpoint_path": checkpoint_path
        }

    @tf.function(input_signature=[tf.TensorSpec(shape=[], dtype=tf.string)])
    def restore(self, checkpoint_path):
        restored_tensors = {}
        for var in self.weights:
            restored = tf.raw_ops.Restore(
                file_pattern=checkpoint_path, tensor_name=var.name, dt=var.dtype,
                name='restore')
            var.assign(restored)
            restored_tensors[var.name] = restored
        return restored_tensors

# %%
# load data
x_total = np.load('../CRC_data/CRC_2nd _random/crc2nd_round1_300_data_object.npy')
y_total = np.load('../CRC_data/CRC_2nd _random/crc2nd_round1_300_label_object.npy')

x_12features = x_total[:, :, :12]
x_train, x_test, y_train, y_test = train_test_split(x_12features, y_total, test_size=0.2, random_state=1004)

y_train_one_hot = to_categorical(y_train, 7)
y_test_one_hot = to_categorical(y_test, 7)

def create_batches(x_data, y_data, batch_size):
    batches_x = []
    batches_y = []

    for i in range(0, len(x_data), batch_size):
        x_batch = x_data[i:i + batch_size]
        y_batch = y_data[i:i + batch_size]

        x_batch_set = []
        for sensor_i in range(SENSOR_NUM):
            x_batch_set.append(x_batch[:, :, (sensor_i * 3):(sensor_i * 3) + 3].astype('float32'))

        batches_x.append(x_batch_set)
        batches_y.append(y_batch.astype('float32'))

    return batches_x, batches_y

batch_x_train_set, batch_y_train_set = create_batches(x_train, y_train_one_hot, BATCH_SIZE)

model = MultiCNN()
model.compile(optimizer=optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# 실제 데이터를 사용하여 모델 빌드
dummy_input = [tf.random.uniform((1, WINDOW_SIZE, SENSOR_FEATURES)) for _ in range(SENSOR_NUM)]
model(dummy_input)

# %%
epochs = np.arange(1, NUM_EPOCHS + 1, 1)
losses = np.zeros([NUM_EPOCHS])

for i in range(NUM_EPOCHS):
    for num, x in enumerate(batch_x_train_set):
        y = batch_y_train_set[num]
        x_input = np.stack(x, axis=0)
        result = model.train(x_input, y)

    losses[i] = result['loss']

    print(f"Finished {i+1} epochs")
    print(f"  loss: {losses[i]:.3f}")

# Save the trained weights to a checkpoint.
model.save(r'/home/chang/Desktop/tensor_lite/model_test.ckpt')

batch_x_test_set, batch_y_test_set = create_batches(x_test, y_test_one_hot, BATCH_SIZE)

count = 0
number = 0
for num, x in enumerate(batch_x_test_set):
    y = batch_y_test_set[num]
    number += y.shape[0]
    x_input = np.stack(x, axis=0)
    result = model.infer(x_input)

    for i in range(result['output'].shape[0]):
        if tf.argmax((result['output'][i])) == y[i].argmax():
            count += 1
# Out:
# Finished 1 epochs
#   loss: 0.616
# Finished 2 epochs
#   loss: 0.368
# Finished 3 epochs
#   loss: 0.229
# Finished 4 epochs
#   loss: 0.308
# Finished 5 epochs
#   loss: 0.191
# Finished 6 epochs
#   loss: 0.220
# Finished 7 epochs
#   loss: 0.118
# Finished 8 epochs
#   loss: 0.122
# Finished 9 epochs
#   loss: 0.120
# Finished 10 epochs
#   loss: 0.094
# Finished 11 epochs
#   loss: 0.176
# Finished 12 epochs
#   loss: 0.084
# Finished 13 epochs
#   loss: 0.049
# Finished 14 epochs
#   loss: 0.166
# Finished 15 epochs
#   loss: 0.131
# Finished 16 epochs
#   loss: 0.076
# Finished 17 epochs
#   loss: 0.049
# Finished 18 epochs
#   loss: 0.023
# Finished 19 epochs
#   loss: 0.164
# Finished 20 epochs
#   loss: 0.105
# Finished 21 epochs
#   loss: 0.035
# Finished 22 epochs
#   loss: 0.114
# Finished 23 epochs
#   loss: 0.049
# Finished 24 epochs
#   loss: 0.070
# Finished 25 epochs
#   loss: 0.024
# Finished 26 epochs
#   loss: 0.056
# Finished 27 epochs
#   loss: 0.022
# Finished 28 epochs
#   loss: 0.114
# Finished 29 epochs
#   loss: 0.037
# Finished 30 epochs
#   loss: 0.012

# %%
SAVED_MODEL_DIR = "saved_model_test"

tf.saved_model.save(
    model,
    SAVED_MODEL_DIR,
    signatures={
        'train':
            model.train.get_concrete_function(),
        'infer':
            model.infer.get_concrete_function(),
        'save':
            model.save.get_concrete_function(),
        'restore':
            model.restore.get_concrete_function()
    })

# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model(SAVED_MODEL_DIR)
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # enable TensorFlow Lite ops.
    tf.lite.OpsSet.SELECT_TF_OPS  # enable TensorFlow ops.
]
converter.experimental_enable_resource_variables = True
tflite_model = converter.convert()

# Save the TFLite model to a file
TFLITE_MODEL_FILE = "multi_cnn_test.tflite"
with open(TFLITE_MODEL_FILE, "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: saved_model_test/assets
# INFO:tensorflow:Assets written to: saved_model_test/assets
# WARNING:absl:Importing a function (__inference_internal_grad_fn_525019) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_internal_grad_fn_525190) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# 2024-09-23 17:17:09.888078: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2024-09-23 17:17:09.888095: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2024-09-23 17:17:09.888197: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: saved_model_test
# 2024-09-23 17:17:09.894833: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2024-09-23 17:17:09.894844: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: saved_model_test
# 2024-09-23 17:17:09.910984: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2024-09-23 17:17:10.025237: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: saved_model_test
# 2024-09-23 17:17:10.080084: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 191885 microseconds.
# 2024-09-23 17:17:10.428905: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428930: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428934: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428937: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428940: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428943: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428945: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428948: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428951: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428953: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428956: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428959: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428961: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428964: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428967: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428969: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428972: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428975: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428977: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428980: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428982: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428985: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428988: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428990: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428993: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.428996: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429001: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429004: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429007: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429009: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429012: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429014: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429017: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429020: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429022: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429025: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429028: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429030: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429033: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429036: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429038: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429041: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429044: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429046: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429049: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429052: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429055: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429057: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429060: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429063: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429065: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429068: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429070: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429073: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429076: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429078: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429081: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429083: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429087: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429089: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429092: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429095: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429097: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429100: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429103: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429105: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429108: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429110: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429113: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429116: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429118: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429121: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429124: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429126: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429129: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429131: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429134: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429137: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429139: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429142: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429144: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429147: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429150: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429152: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429155: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429162: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429164: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429167: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429169: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429172: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429175: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429178: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429180: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429183: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429185: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429188: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429190: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429193: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429195: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429198: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429200: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429203: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429205: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429208: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429210: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429213: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429215: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429218: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429220: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429223: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429225: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429228: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429230: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429258: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429261: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429263: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429266: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429269: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429271: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429274: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429276: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429279: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429282: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429284: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429287: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429289: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429292: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429294: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429297: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429299: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429303: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429305: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429308: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429310: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429313: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429315: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429317: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429320: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429322: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429325: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429327: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429329: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429332: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429334: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429337: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429339: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429342: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429344: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429346: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429349: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429351: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429354: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429356: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429359: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429362: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429364: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429366: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429369: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429371: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429374: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429376: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429378: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429381: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429383: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429386: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429388: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429391: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429393: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429395: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429404: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429407: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429409: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429412: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429414: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429417: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429419: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429422: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429424: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429426: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429429: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429431: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429434: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429441: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429445: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429448: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429450: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429453: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429456: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429458: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429461: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429463: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429465: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429468: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429470: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429473: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429475: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429478: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429480: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429492: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429494: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429497: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429499: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429502: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429504: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429507: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429509: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429512: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429514: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429516: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429519: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429521: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429524: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429526: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429529: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429531: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429534: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429536: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429538: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429541: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429544: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429546: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429549: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429551: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429554: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429556: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429558: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429561: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429563: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429566: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429568: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429571: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429573: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429576: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429578: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429580: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429583: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429585: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429588: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429590: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429593: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429595: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429597: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429600: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429602: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429605: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429607: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429610: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429612: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429614: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429617: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429620: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429622: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429625: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429627: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429630: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429632: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429634: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429637: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429639: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429642: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429644: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429647: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429649: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429652: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429654: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429656: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429659: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429661: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429664: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429666: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429669: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429671: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429673: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429676: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429678: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429681: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429683: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429686: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429688: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429691: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429693: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429695: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# 2024-09-23 17:17:10.429698: E tensorflow/compiler/mlir/lite/stablehlo/transforms/op_stat_pass.cc:119] Unsupported data type.
# Summary on the non-converted ops:
# ---------------------------------
#  * Accepted dialects: tfl, builtin, func
#  * Non-Converted Ops: 240, Total Ops 1962, % non-converted = 12.23 %
#  * 170 ARITH ops, 69 TF ops, 1 TF_SAVED_MODEL ops
#
# - arith.constant:  170 occurrences  (: 29, i64: 2, f32: 99, i32: 40)
#
#
#
# - tf.BroadcastGradientArgs:    1 occurrences  (i32: 1)
# - tf.ConcatOffset:    1 occurrences  (i32: 1)
# - tf.Conv2DBackpropFilter:   12 occurrences  (f32: 12)
# - tf.MaxPoolGrad:   12 occurrences  (f32: 12)
# - tf.ReluGrad:   13 occurrences  (f32: 13)
# - tf.Restore:   28 occurrences  (f32: 28)
# - tf.Save:    1 occurrences
# - tf.ShapeN:    1 occurrences  (i32: 1)
# - tf_saved_model.session_initializer:    1 occurrences
#   (i64: 29, f32: 112)
#
#   (f32: 6)
#
#   (f32: 29)
#   (f32: 2, i32: 2)
#   (f32: 24)
#   (f32: 58)
#   (i1: 2)
#   (f32: 49)
#   (f32: 2)
#   (f32: 8)
#   (i1: 1)
#   (f32: 1)
#   (f32: 24)
#   (f32: 116)
#   (f32: 1)
#
#   (f32: 56)
#   (f32: 1)
#   (i64: 29, f32: 224)
#   (i32: 1)
#   (f32: 127)
#   (f32: 2)
#   (f32: 3)
#   (i32: 51)
#   (f32: 4, i32: 3)
#   (f32: 3)
#   (f32: 56)
#   (f32: 28)
#   (f32: 141)
#   (f32: 17)
#   (f32: 2)
#   (f32: 32)
#   (f32: 8)
#   (: 254)
# 2024-09-23 17:17:10.479790: W tensorflow/compiler/mlir/lite/flatbuffer_export.cc:2921] TFLite interpreter needs to link Flex delegate in order to run the model since it contains the following Select TFop(s):
# Flex ops: FlexBroadcastGradientArgs, FlexConcatOffset, FlexConv2DBackpropFilter, FlexMaxPoolGrad, FlexReluGrad, FlexRestore, FlexSave, FlexShapeN
# Details:
# 	tf.BroadcastGradientArgs(tensor<2xi32>, tensor<2xi32>) -> (tensor<?xi32>, tensor<?xi32>) : {device = ""}
# 	tf.ConcatOffset(tensor<i32>, tensor<2xi32>, tensor<2xi32>, tensor<2xi32>, tensor<2xi32>) -> (tensor<2xi32>, tensor<2xi32>, tensor<2xi32>, tensor<2xi32>) : {device = ""}
# 	tf.Conv2DBackpropFilter(tensor<?x1x150x32xf32>, tensor<4xi32>, tensor<?x1x150x64xf32>) -> (tensor<1x3x32x64xf32>) : {data_format = "NHWC", device = "", dilations = [1, 1, 1, 1], explicit_paddings = [], padding = "SAME", strides = [1, 1, 1, 1], use_cudnn_on_gpu = true}
# 	tf.Conv2DBackpropFilter(tensor<?x1x300x3xf32>, tensor<4xi32>, tensor<?x1x300x32xf32>) -> (tensor<1x3x3x32xf32>) : {data_format = "NHWC", device = "", dilations = [1, 1, 1, 1], explicit_paddings = [], padding = "SAME", strides = [1, 1, 1, 1], use_cudnn_on_gpu = true}
# 	tf.Conv2DBackpropFilter(tensor<?x1x75x64xf32>, tensor<4xi32>, tensor<?x1x75x128xf32>) -> (tensor<1x3x64x128xf32>) : {data_format = "NHWC", device = "", dilations = [1, 1, 1, 1], explicit_paddings = [], padding = "SAME", strides = [1, 1, 1, 1], use_cudnn_on_gpu = true}
# 	tf.MaxPoolGrad(tensor<?x150x1x64xf32>, tensor<?x75x1x64xf32>, tensor<?x75x1x64xf32>) -> (tensor<?x150x1x64xf32>) : {data_format = "NHWC", device = "", explicit_paddings = [], ksize = [1, 2, 1, 1], padding = "VALID", strides = [1, 2, 1, 1]}
# 	tf.MaxPoolGrad(tensor<?x300x1x32xf32>, tensor<?x150x1x32xf32>, tensor<?x150x1x32xf32>) -> (tensor<?x300x1x32xf32>) : {data_format = "NHWC", device = "", explicit_paddings = [], ksize = [1, 2, 1, 1], padding = "VALID", strides = [1, 2, 1, 1]}
# 	tf.MaxPoolGrad(tensor<?x75x1x128xf32>, tensor<?x37x1x128xf32>, tensor<?x37x1x128xf32>) -> (tensor<?x75x1x128xf32>) : {data_format = "NHWC", device = "", explicit_paddings = [], ksize = [1, 2, 1, 1], padding = "VALID", strides = [1, 2, 1, 1]}
# 	tf.ReluGrad(tensor<?x150x64xf32>, tensor<?x150x64xf32>) -> (tensor<?x150x64xf32>) : {device = ""}
# 	tf.ReluGrad(tensor<?x256xf32>, tensor<?x256xf32>) -> (tensor<?x256xf32>) : {device = ""}
# 	tf.ReluGrad(tensor<?x300x32xf32>, tensor<?x300x32xf32>) -> (tensor<?x300x32xf32>) : {device = ""}
# 	tf.ReluGrad(tensor<?x75x128xf32>, tensor<?x75x128xf32>) -> (tensor<?x75x128xf32>) : {device = ""}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<128xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<18944x256xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<256x7xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<256xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<32xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<3x32x64xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<3x3x32xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<3x64x128xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<64xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Restore(tensor<!tf_type.string>, tensor<!tf_type.string>) -> (tensor<7xf32>) : {device = "", preferred_shard = -1 : i64}
# 	tf.Save(tensor<!tf_type.string>, tensor<28x!tf_type.string>, tensor<3x3x32xf32>, tensor<32xf32>, tensor<3x32x64xf32>, tensor<64xf32>, tensor<3x64x128xf32>, tensor<128xf32>, tensor<3x3x32xf32>, tensor<32xf32>, tensor<3x32x64xf32>, tensor<64xf32>, tensor<3x64x128xf32>, tensor<128xf32>, tensor<3x3x32xf32>, tensor<32xf32>, tensor<3x32x64xf32>, tensor<64xf32>, tensor<3x64x128xf32>, tensor<128xf32>, tensor<3x3x32xf32>, tensor<32xf32>, tensor<3x32x64xf32>, tensor<64xf32>, tensor<3x64x128xf32>, tensor<128xf32>, tensor<18944x256xf32>, tensor<256xf32>, tensor<256x7xf32>, tensor<7xf32>) -> () : {device = ""}
# 	tf.ShapeN(tensor<?x4736xf32>, tensor<?x4736xf32>, tensor<?x4736xf32>, tensor<?x4736xf32>) -> (tensor<2xi32>, tensor<2xi32>, tensor<2xi32>, tensor<2xi32>) : {device = ""}
# See instructions: https://www.tensorflow.org/lite/guide/ops_select
